# %%
import numpy as np
import matplotlib.pylab as plt

# %%
data = np.genfromtxt("br.sm2", skip_header = 2)

plt.plot(data[:,0],data[:,6],color="orange")
plt.title("Plot 1: HDECAY.")
plt.xlabel("Higgs mass. (GeV)")
plt.ylabel("Width. (GeV)")
plt.yscale('log')
plt.xscale('log')
plt.savefig("plt1.jpg")
